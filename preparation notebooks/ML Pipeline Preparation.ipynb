# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import re
import pandas as pd
import numpy as np

import nltk
nltk.download(['punkt', 'wordnet'])
nltk.download('stopwords')

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords

from sqlalchemy import create_engine
import sqlite3
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bernardogarcia/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/bernardogarcia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/bernardogarcia/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# **Note** - We want to classify the messages into categories. `messages` will be the input samples (X) and `categories` (y) will be the predicted classes.

# %%
# Function to load data from database
def load_data():
    engine = create_engine('sqlite:///InsertDatabaseName.db')
    df = pd.read_sql_table(table_name='InsertTableName', con=engine)
    X = df['message'].values
    y = df.drop(['id', 'message', 'original', 'genre'], axis=1).values
    return X, y, df

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    ''' This function takes an array with the messages and returns an array with the tokenized text.
    
    INPUT:
    
    text - Messages in the df stored in the database (array-like object, string)
    
    OUTPUT:
    
    lemmed_text - Tokenized and lemmed messages in the df stored in the database (array-like object, string)
    '''
    
    # Normalize text to all lower case and remove punctuation
    text = re.sub(r"[^a-zA-Z0-9]"," ", text)
    lower_case_text = text.lower()
    
    # Tokenize text
    tokens = word_tokenize(lower_case_text)
    
    # Remove stopwords
    words = [w for w in tokens if w not in stopwords.words("english")]
    
    # Instantiate lemmatizer
    lemmatizer = WordNetLemmatizer()
    
    # Reduce words to their root form
    lemmed_text = [WordNetLemmatizer().lemmatize(w, pos='v') for w in words]
        
    return lemmed_text

# %%
X, y, df = load_data()

# test out function
for message in X[:5]:
    tokens = tokenize(message)
    print(message)
    print(tokens, '\n')
# Out:
# Weather update - a cold front from Cuba that could pass over Haiti
# ['weather', 'update', 'cold', 'front', 'cuba', 'could', 'pass', 'haiti']
#
# Is the Hurricane over or is it not over
# ['hurricane']
#
# Looking for someone but no name
# ['look', 'someone', 'name']
#
# UN reports Leogane 80-90 destroyed. Only Hospital St. Croix functioning. Needs supplies desperately.
# ['un', 'report', 'leogane', '80', '90', 'destroy', 'hospital', 'st', 'croix', 'function', 'need', 'supply', 'desperately']
#
# says: west side of Haiti, rest of the country today and tonight
# ['say', 'west', 'side', 'haiti', 'rest', 'country', 'today', 'tonight']

# %% [markdown]
# ### 3. Build a machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.multioutput import MultiOutputClassifier
from sklearn.neighbors import KNeighborsClassifier

pipeline = Pipeline([
    ('vect', CountVectorizer(tokenizer=tokenize)),
    ('tfidf', TfidfTransformer()),
    ('clf', MultiOutputClassifier(KNeighborsClassifier(), n_jobs=-1))
])

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
from sklearn.model_selection import train_test_split

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train pipeline on train set
pipeline.fit(X_train, y_train)

# Predict on test data
y_pred = pipeline.predict(X_test)

# %% [markdown]
# ### 5. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.

# %%
y_test.shape
# Out:
# (7854, 36)

# %%
y_pred.shape
# Out:
# (7854, 36)

# %%
# Category labels

category_labels = list(df.columns[4:])

# %%
from sklearn.metrics import classification_report

for i, label in zip(range(y_pred.shape[1]), category_labels):
        print('Category:', label, classification_report(y_test[:, i], y_pred[:, i],
                                                        target_names=['Negative', 'Positive'],labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#     Negative       0.52      0.47      0.49      1869
#     Positive       0.83      0.87      0.85      5926
#
#    micro avg       0.77      0.77      0.77      7795
#    macro avg       0.68      0.67      0.67      7795
# weighted avg       0.76      0.77      0.76      7795
#
#               precision    recall  f1-score   support
#
#     Negative       0.87      0.98      0.92      6512
#     Positive       0.74      0.28      0.41      1342
#
#     accuracy                           0.86      7854
#    macro avg       0.80      0.63      0.66      7854
# weighted avg       0.85      0.86      0.83      7854
#
#               precision    recall  f1-score   support
#
#     Negative       1.00      1.00      1.00      7816
#     Positive       0.00      0.00      0.00        38
#
#     accuracy                           1.00      7854
#    macro avg       0.50      0.50      0.50      7854
# weighted avg       0.99      1.00      0.99      7854
#
#               precision    recall  f1-score   support
#
#     Negative       0
7854
#
#               precision    recall  f1-score   support
#
#     Negative       0.95      1.00      0.97      7453
#     Positive       0.62      0.02      0.05       401
#
#     accuracy                           0.95      7854
#    macro avg       0.79      0.51      0.51      7854
# weighted avg       0.93      0.95      0.93      7854
#
#               precision    recall  f1-score   support
#
#     Negative       0.83      0.98      0.90      6319
#     Positive       0.69      0.18      0.28      1535
#
#     accuracy                           0.82      7854
#    macro avg       0.76      0.58      0.59      7854
# weighted avg       0.80      0.82      0.78      7854

# %%
# Simple example to understand classification_report output
y_real = [1, 0, 0, 1, 1]
y_predic = [1, 0, 1, 0, 1]

# %%
print('Class 1', classification_report(y_predic, y_real, target_names=['Negative', 'Positive'],labels=[0, 1]))
# Out:
# Class 1               precision    recall  f1-score   support
#
#     Negative       0.50      0.50      0.50         2
#     Positive       0.67      0.67      0.67         3
#
#     accuracy                           0.60         5
#    macro avg       0.58      0.58      0.58         5
# weighted avg       0.60      0.60      0.60         5

# %% [markdown]
# ### 6. Improve your model
# Use grid search to find better parameters.

# %%
# Display parameters in the pipeline
pipeline.get_params()
# Out:
# {'memory': None,
#  'steps': [('vect',
#    CountVectorizer(tokenizer=<function tokenize at 0x106857ca0>)),
#   ('tfidf', TfidfTransformer()),
#   ('clf', MultiOutputClassifier(estimator=KNeighborsClassifier(), n_jobs=-1))],
#  'verbose': False,
#  'vect': CountVectorizer(tokenizer=<function tokenize at 0x106857ca0>),
#  'tfidf': TfidfTransformer(),
#  'clf': MultiOutputClassifier(estimator=KNeighborsClassifier(), n_jobs=-1),
#  'vect__analyzer': 'word',
#  'vect__binary': False,
#  'vect__decode_error': 'strict',
#  'vect__dtype': numpy.int64,
#  'vect__encoding': 'utf-8',
#  'vect__input': 'content',
#  'vect__lowercase': True,
#  'vect__max_df': 1.0,
#  'vect__max_features': None,
#  'vect__min_df': 1,
#  'vect__ngram_range': (1, 1),
#  'vect__preprocessor': None,
#  'vect__stop_words': None,
#  'vect__strip_accents': None,
#  'vect__token_pattern': '(?u)\\b\\w\\w+\\b',
#  'vect__tokenizer': <function __main__.tokenize(text)>,
#  'vect__vocabulary': None,
#  'tfidf__norm': 'l2',
#  'tfidf__smooth_idf': True,
#  'tfidf__sublinear_tf': False,
#  'tfidf__use_idf': True,
#  'clf__estimator__algorithm': 'auto',
#  'clf__estimator__leaf_size': 30,
#  'clf__estimator__metric': 'minkowski',
#  'clf__estimator__metric_params': None,
#  'clf__estimator__n_jobs': None,
#  'clf__estimator__n_neighbors': 5,
#  'clf__estimator__p': 2,
#  'clf__estimator__weights': 'uniform',
#  'clf__estimator': KNeighborsClassifier(),
#  'clf__n_jobs': -1}

# %%
#'tfidf__norm': ()'l2'),
    #'tfidf__smooth_idf': (True, False),
    #'tfidf__sublinear_tf': (True, False),

# %%
from sklearn.model_selection import GridSearchCV

parameters = {
    'clf__estimator__n_neighbors': [2, 5],
    'clf__estimator__weights': ('uniform', 'distance')  
}

cv = GridSearchCV(pipeline, param_grid=parameters)
cv.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('vect',
#                                         CountVectorizer(tokenizer=<function tokenize at 0x106857ca0>)),
#                                        ('tfidf', TfidfTransformer()),
#                                        ('clf',
#                                         MultiOutputClassifier(estimator=KNeighborsClassifier(),
#                                                               n_jobs=-1))]),
#              param_grid={'clf__estimator__n_neighbors': [2, 5],
#                          'clf__estimator__weights': ('uniform', 'distance')})

# %% [markdown]
# ### 7. Test your model
# Show the accuracy, precision, and recall of the tuned model.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
# Predict on test data
y_pred = cv.predict(X_test)

# %%
# Print classification_report
category_labels = list(df.columns[4:])

for i, label in zip(range(y_pred.shape[1]), category_labels):
        print('Category:', label,'\n', classification_report(y_test[:, i], y_pred[:, i],
                                                        target_names=['Negative', 'Positive'],labels=[0, 1]))
# Out:
# Category: related
#                precision    recall  f1-score   support
#
#     Negative       0.52      0.47      0.49      1869
#     Positive       0.83      0.87      0.85      5926
#
#    micro avg       0.77      0.77      0.77      7795
#    macro avg       0.68      0.67      0.67      7795
# weighted avg       0.76      0.77      0.76      7795
#
# Category: request
#                precision    recall  f1-score   support
#
#     Negative       0.87      0.98      0.92      6512
#     Positive       0.74      0.28      0.41      1342
#
#     accuracy                           0.86      7854
#    macro avg       0.80      0.63      0.66      7854
# weighted avg       0.85      0.86      0.83      7854
#
# Category: offer
#                precision    recall  f1-score   support
#
#     Negative       1.00      1.00      1.00      7816
#     Positive       0.00      0.00      0.00        38
#
#     accuracy                           1.00      7854
#    macro avg       0.50      0.50      0.50      7854
# weighted avg       0.99      1.00      0.99      7854
#
# Category: aid_related
#                precision    recall  f1-score   support
#
#     Negative       0.64      0.94      0.77      4612
#     Positive       0.76      0.26      0.39      3242
#
#     accuracy                           0.66      7854
#    macro avg       0.70      0.60      0.58      7854
# weighted avg       0.69      0.66      0.61      7854
#
# Category: medical_help
#                precision    recall  f1-score   support
#
#     Negative       0.92      1.00      0.96      7234
#     Positive       0.62      0.03      0.06       620
#
#     accuracy                           0.92      7854
#    macro avg       0.77      0.52      0.51      7854
# weighted avg       0.90      0.92      0.89      7854
#
# Category: medical_products
#                precision    recall  f1-score   support
#
#     Negative       0.96      1.00      0.98      7486
#     Positive       0.64      0.06      0.11       368
#
#     accuracy                           0.95      7854
#    macro avg       0.80      0.53      0.55      7854
# weighted avg       0.94      0.95      0.94      7854
#
# Category: search_and_rescue
#                precision    recall  f1-score   support
#
#     Negative       0.97      1.00      0.99      7631
#     Positive       1.00      0.02      0.04       223
#
#     accuracy                           0.97      7854
#    macro avg       0.99      0.51      0.51      7854
# weighted avg       0.97      0.97      0.96      7854
#
# Category: security
#                precision    recall  f1-score   support
#
#     Negative       0.98      1.00      0.99      7697
#     Positive       0.00      0.00      0.00       157
#
#     accuracy                           0.98      7854
#    macro avg       0.49      0.50      0.49      7854
# weighted avg       0.96      0.98      0.97      7854
#
# Category: military
#                precision    recall  f1-score   support
#
#     Negative       0.97      1.00      0.98      7591
#     Positive       0.67      0.05      0.10       263
#
#     accuracy                           0.97      7854
#    macro avg       0.82      0.53      0.54      7854
# weighted avg       0.96      0.97      0.95      7854
#
# Category: child_alone
#                precision    recall  f1-score   support
#
#     Negative       1.00      1.00      1.00      7854
#     Positive       0.00      0.00      0.00         0
#
#    micro avg       1.00      1.00      1.00      7854
#    macro avg       0.50      0.50      0.50      7854
# weighted avg       1.00      1.00      1.00      7854
#
# Category: water
#                precision    recall  f1-score   support
#
#     Negative       0.94      1.00      0.97      7353
#     Positive       0.73      0.11      0.20       501
#
#     accuracy                           0.94      7854
#    macro avg       0.84      0.56      0.58      7854
# weighted avg       0.93      0.94      0.92      7854
#
# Category: food
#                precision    recall  f1-score   support
#
#     Negative       0.91      0.99      0.95      6999
#     Positive       0.76      0.19      0.30       855
#
#     accuracy                           0.91      7854
#    macro avg       0.83      0.59      0.63      7854
# weighted avg       0.89      0.91      0.88      7854
#
# Category: shelter
#                precision    recall  f1-score   support
#
#     Negative       0.92      1.00      0.96      7172
#     Positive       0.76      0.10      0.18       682
#
#     accuracy                           0.92      7854
#    macro avg       0.84      0.55      0.57      7854
# weighted avg       0.91      0.92      0.89      7854
#
# Category: clothing
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      0.99      7747
#     Positive       0.39      0.07      0.11       107
#
#     accuracy                           0.99      7854
#    macro avg       0.69      0.53      0.55      7854
# weighted avg       0.98      0.99      0.98      7854
#
# Category: money
#                precision    recall  f1-score   support
#
#     Negative       0.98      1.00      0.99      7675
#     Positive       0.45      0.03      0.05       179
#
#     accuracy                           0.98      7854
#    macro avg       0.72      0.51      0.52      7854
# weighted avg       0.97      0.98      0.97      7854
#
# Category: missing_people
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      0.99      7774
#     Positive       0.00      0.00      0.00        80
#
#     accuracy                           0.99      7854
#    macro avg       0.49      0.50      0.50      7854
# weighted avg       0.98      0.99      0.98      7854
#
# Category: refugees
#                precision    recall  f1-score   support
#
#     Negative       0.96      1.00      0.98      7554
#     Positive       0.43      0.01      0.02       300
#
#     accuracy                           0.96      7854
#    macro avg       0.70      0.50      0.50      7854
# weighted avg       0.94      0.96      0.94      7854
#
# Category: death
#                precision    recall  f1-score   support
#
#     Negative       0.96      1.00      0.98      7491
#     Positive       0.83      0.08      0.15       363
#
#     accuracy                           0.96      7854
#    macro avg       0.89      0.54      0.56      7854
# weighted avg       0.95      0.96      0.94      7854
#
# Category: other_aid
#                precision    recall  f1-score   support
#
#     Negative       0.87      0.99      0.93      6828
#     Positive       0.45      0.04      0.07      1026
#
#     accuracy                           0.87      7854
#    macro avg       0.66      0.51      0.50      7854
# weighted avg       0.82      0.87      0.82      7854
#
# Category: infrastructure_related
#                precision    recall  f1-score   support
#
#     Negative       0.93      1.00      0.96      7300
#     Positive       0.56      0.01      0.02       554
#
#     accuracy                           0.93      7854
#    macro avg       0.74      0.50      0.49      7854
# weighted avg       0.90      0.93      0.90      7854
#
# Category: transport
#                precision    recall  f1-score   support
#
#     Negative       0.95      1.00      0.98      7490
#     Positive       0.77      0.03      0.05       364
#
#     accuracy                           0.95      7854
#    macro avg       0.86      0.51      0.51      7854
# weighted avg       0.95      0.95      0.93      7854
#
# Category: buildings
#                precision    recall  f1-score   support
#
#     Negative       0.95      1.00      0.97      7414
#     Positive       0.72      0.04      0.08       440
#
#     accuracy                           0.95      7854
#    macro avg       0.83      0.52      0.52      7854
# weighted avg       0.93      0.95      0.92      7854
#
# Category: electricity
#                precision    recall  f1-score   support
#
#     Negative       0.98      1.00      0.99      7700
#     Positive       0.78      0.05      0.09       154
#
#     accuracy                           0.98      7854
#    macro avg       0.88      0.52      0.54      7854
# weighted avg       0.98      0.98      0.97      7854
#
# Category: tools
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      1.00      7813
#     Positive       0.00      0.00      0.00        41
#
#     accuracy                           0.99      7854
#    macro avg       0.50      0.50      0.50      7854
# weighted avg       0.99      0.99      0.99      7854
#
# Category: hospitals
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      0.99      7763
#     Positive       0.00      0.00      0.00        91
#
#     accuracy                           0.99      7854
#    macro avg       0.49      0.50      0.50      7854
# weighted avg       0.98      0.99      0.98      7854
#
# Category: shops
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      1.00      7802
#     Positive       0.00      0.00      0.00        52
#
#     accuracy                           0.99      7854
#    macro avg       0.50      0.50      0.50      7854
# weighted avg       0.99      0.99      0.99      7854
#
# Category: aid_centers
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      0.99      7742
#     Positive       0.00      0.00      0.00       112
#
#     accuracy                           0.99      7854
#    macro avg       0.49      0.50      0.50      7854
# weighted avg       0.97      0.99      0.98      7854
#
# Category: other_infrastructure
#                precision    recall  f1-score   support
#
#     Negative       0.95      1.00      0.98      7492
#     Positive       0.25      0.00      0.01       362
#
#     accuracy                           0.95      7854
#    macro avg       0.60      0.50      0.49      7854
# weighted avg       0.92      0.95      0.93      7854
#
# Category: weather_related
#                precision    recall  f1-score   support
#
#     Negative       0.78      0.97      0.86      5718
#     Positive       0.79      0.25      0.38      2136
#
#     accuracy                           0.78      7854
#    macro avg       0.78      0.61      0.62      7854
# weighted avg       0.78      0.78      0.73      7854
#
# Category: floods
#                precision    recall  f1-score   support
#
#     Negative       0.93      1.00      0.96      7237
#     Positive       0.78      0.07      0.13       617
#
#     accuracy                           0.93      7854
#    macro avg       0.85      0.54      0.55      7854
# weighted avg       0.91      0.93      0.90      7854
#
# Category: storm
#                precision    recall  f1-score   support
#
#     Negative       0.92      1.00      0.96      7138
#     Positive       0.74      0.11      0.20       716
#
#     accuracy                           0.92      7854
#    macro avg       0.83      0.56      0.58      7854
# weighted avg       0.90      0.92      0.89      7854
#
# Category: fire
#                precision    recall  f1-score   support
#
#     Negative       0.99      1.00      0.99      7772
#     Positive       0.67      0.02      0.05        82
#
#     accuracy                           0.99      7854
#    macro avg       0.83      0.51      0.52      7854
# weighted avg       0.99      0.99      0.98      7854
#
# Category: earthquake
#                precision    recall  f1-score   support
#
#     Negative       0.94      0.99      0.96      7135
#     Positive       0.79      0.35      0.49       719
#
#     accuracy                           0.93      7854
#    macro avg       0.87      0.67      0.72      7854
# weighted avg       0.92      0.93      0.92      7854
#
# Category: cold
#                precision    recall  f1-score   support
#
#     Negative       0.98      1.00      0.99      7690
#     Positive       0.86      0.04      0.07       164
#
#     accuracy                           0.98      7854
#    macro avg       0.92      0.52      0.53      7854
# weighted avg       0.98      0.98      0.97      7854
#
# Category: other_weather
#                precision    recall  f1-score   support
#
#     Negative       0.95      1.00      0.97      7453
#     Positive       0.62      0.02      0.05       401
#
#     accuracy                           0.95      7854
#    macro avg       0.79      0.51      0.51      7854
# weighted avg       0.93      0.95      0.93      7854
#
# Category: direct_report
#                precision    recall  f1-score   support
#
#     Negative       0.83      0.98      0.90      6319
#     Positive       0.69      0.18      0.28      1535
#
#     accuracy                           0.82      7854
#    macro avg       0.76      0.58      0.59      7854
# weighted avg       0.80      0.82      0.78      7854

# %% [markdown]
# ### 8. Try improving your model further. Here are a few ideas:
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
# TODO

# %% [markdown]
# ### 9. Export your model as a pickle file

# %%
# Save the model to disk
pkl_filename = 'KNeighborsClassifier.pkl'
pickle.dump(model, open(filename, 'wb'))

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
